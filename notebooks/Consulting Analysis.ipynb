# %%
= Business Analysis =
# Out:
#   File "<ipython-input-1-786bd5a61f69>", line 1
#     = Business Analysis =
#     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

df_contracts = pd.read_csv('../data/contracts.csv')
df_contracts.head()

df_customers = pd.read_csv('../data/customers.csv')
df_customers.head()

df_customers.rename(columns={'id':'customer_id'}, inplace=True)
df_customers.head()

df_customers.set_index('customer_id', inplace=True)
df_customers.head()

df_contracts = df_contracts.set_index('customer_id')
df_contracts.head()

df = df_contracts.join(df_customers, how='left')
df.head(25)

gk = df.groupby('deposit') 
gk.first() 

df_contracts.join(df_customers, how='left')
# Out:
#              contract_id contract_start  contract_term      deposit  \
# customer_id
# 1                     41      5/31/2019             24  $86,000.00
# 1                    358      6/18/2019             13  $74,000.00
# 1                    400      8/11/2019             19  $38,000.00
# 1                    424      3/13/2019             15  $77,000.00
# 1                    438     10/16/2019             22  $39,000.00
# ...                  ...            ...            ...          ...
# 200                  284     12/28/2019             17  $78,000.00
# 200                  540      4/17/2019              3  $65,000.00
# 200                  630      11/1/2019             12  $85,000.00
# 200                  862      10/2/2019             21  $48,000.00
# 200                  973      8/21/2019              1  $47,000.00
#
#              monthly_amt    company         sector  \
# customer_id
# 1            $11,200.00   Bubblebox  Capital Goods
# ...

# %%
df.groupby('state').agg({'contract_id' : 'count', 'company':pd.Series.nunique}).sort_values('company', ascending=False)
# Out:
#        contract_id  company
# state
# TX             104       21
# CA              88       17
# FL              70       15
# NY              43       11
# WA              54        9
# DC              32        8
# PA              29        7
# KS              43        7
# VA              35        7
# OH              33        6
# LA              33        6
# WI              24        6
# CO              34        6
# OR              22        5
# OK              34        5
# AZ              22        5
# MO              26        5
# GA              15        4
# MD              18        4
# MI              20        4
# IL              23        4
# TN              16        4
# NC              25        4
# ID              18        3
# NE              22        3
# MN              18        3
# DE              14        3
# IN              11        3
# NV               9        2
# CT              11        2
# SC               5        1
# AK               8        1
# ...

# %%
import re
df.loc[:, 'deposit'] = pd.to_numeric([re.sub('[^0-9]','',str(s)) for s in df['deposit']])
df
# Out:
#              contract_id contract_start  contract_term  deposit  monthly_amt  \
# customer_id
# 1                     41      5/31/2019             24  8600000  $11,200.00
# 1                    358      6/18/2019             13  7400000  $19,000.00
# 1                    400      8/11/2019             19  3800000   $8,800.00
# 1                    424      3/13/2019             15  7700000  $14,300.00
# 1                    438     10/16/2019             22  3900000  $20,000.00
# ...                  ...            ...            ...      ...          ...
# 200                  284     12/28/2019             17  7800000  $17,600.00
# 200                  540      4/17/2019              3  6500000   $9,800.00
# 200                  630      11/1/2019             12  8500000  $12,600.00
# 200                  862      10/2/2019             21  4800000   $6,500.00
# 200                  973      8/21/2019              1  4700000  $12,300.00
#
#                company         sector  \
# ...

# %%
import re
df.loc[:, 'deposit'] = pd.to_numeric([re.sub('[^0-9]','',str(s)) for s in df['deposit']])
df
# Out:
#              contract_id contract_start  contract_term  deposit  monthly_amt  \
# customer_id
# 1                     41      5/31/2019             24  8600000  $11,200.00
# 1                    358      6/18/2019             13  7400000  $19,000.00
# 1                    400      8/11/2019             19  3800000   $8,800.00
# 1                    424      3/13/2019             15  7700000  $14,300.00
# 1                    438     10/16/2019             22  3900000  $20,000.00
# ...                  ...            ...            ...      ...          ...
# 200                  284     12/28/2019             17  7800000  $17,600.00
# 200                  540      4/17/2019              3  6500000   $9,800.00
# 200                  630      11/1/2019             12  8500000  $12,600.00
# 200                  862      10/2/2019             21  4800000   $6,500.00
# 200                  973      8/21/2019              1  4700000  $12,300.00
#
#                company         sector  \
# ...

# %%
import re
df.loc[:, 'monthly_amt'] = pd.to_numeric([re.sub('[^0-9]','',str(s)) for s in df['monthly_amt']])
df
# Out:
#              contract_id contract_start  contract_term  deposit  monthly_amt  \
# customer_id
# 1                     41      5/31/2019             24  8600000      1120000
# 1                    358      6/18/2019             13  7400000      1900000
# 1                    400      8/11/2019             19  3800000       880000
# 1                    424      3/13/2019             15  7700000      1430000
# 1                    438     10/16/2019             22  3900000      2000000
# ...                  ...            ...            ...      ...          ...
# 200                  284     12/28/2019             17  7800000      1760000
# 200                  540      4/17/2019              3  6500000       980000
# 200                  630      11/1/2019             12  8500000      1260000
# 200                  862      10/2/2019             21  4800000       650000
# 200                  973      8/21/2019              1  4700000      1230000
#
# ...

# %%
df['contract_amount'] = df['deposit'] + (df['contract_term']*df['monthly_amt'])
df.head()
# Out:
#              contract_id contract_start  contract_term  deposit  monthly_amt  \
# customer_id
# 1                     41      5/31/2019             24  8600000      1120000
# 1                    358      6/18/2019             13  7400000      1900000
# 1                    400      8/11/2019             19  3800000       880000
# 1                    424      3/13/2019             15  7700000      1430000
# 1                    438     10/16/2019             22  3900000      2000000
#
#                company         sector                       industry  \
# customer_id
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
#
# ...

# %%
df['sector'] = df['sector'].fillna('')
df.loc[df['contract_term']<2]
# Out:
#              contract_id contract_start  contract_term  deposit  monthly_amt  \
# customer_id
# 3                    361      8/11/2019              1  4900000      1790000
# 3                    596      12/1/2019              1  1900000      1350000
# 15                    84       4/4/2019              1  6500000      2260000
# 15                   105      1/31/2019              1  6100000      2020000
# 16                   211      6/15/2019              1  3400000      1420000
# 21                   309      12/9/2019              1  4400000      2270000
# 22                   503     11/10/2019              1  6400000      2040000
# 22                   548      7/13/2019              1  5500000       530000
# 29                   677      8/22/2019              1  2400000      2040000
# 40                   142     10/19/2019              1  2500000      2480000
# 51                   628       7/8/2019              1  6700000      2400000
# ...

# %%
df.groupby('contract_amount').agg({'state': 'count', 'company':pd.Series.nunique}).sort_values('contract_amount', ascending=False)
# Out:
#                  state  company
# contract_amount
# 66900000             1        1
# 65780000             1        1
# 65000000             1        1
# 63120000             1        1
# 62160000             1        1
# ...                ...      ...
# 2850000              1        1
# 2840000              1        1
# 2530000              1        1
# 2160000              1        1
# 2090000              1        1
#
# [852 rows x 2 columns]

# %%
df[['state', 'contract_amount', 'contract_id']].sort_values('contract_amount', ascending=False).head(10)
# Out:
#             state  contract_amount  contract_id
# customer_id
# 198            DE         66900000          945
# 165            CA         65780000          566
# 169            CA         65000000          408
# 143            FL         63120000          518
# 20             WA         62160000          761
# 116            PA         61680000          127
# 101            KS         61100000          126
# 23             MN         61040000          695
# 198            DE         60700000          508
# 1              CA         60460000          657

# %%
= Conclusion =
# Out:
#   File "<ipython-input-11-e9f6fdd879a8>", line 1
#     = Conclusion =
#     ^
# SyntaxError: invalid syntax

# %%
#reasoning
print(" The new headquarters should be set up in California. Even though the number one count of contracts is in Texas, out of the top ten highest contract amounts, 3 of them are in California. Plus, California also has the second highest count of contracts. This state is a heavily active location that is aggresively gaining capital.")
# Out:
#  The new headquarters should be set up in California. Even though the number one count of contracts is in Texas, out of the top ten highest contract amounts, 3 of them are in California. Plus, California also has the second highest count of contracts. This state is a heavily active location that is aggresively gaining capital.
