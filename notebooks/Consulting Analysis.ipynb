# %%
import pandas as pd

# %%
df_contracts = pd.read_csv('../data/contracts.csv')
df_contracts.head()
# Out:
#    contract_id  customer_id contract_start  contract_term      deposit  \
# 0            1          127      8/17/2019             12  $53,000.00
# 1            2          119      12/1/2019             22  $77,000.00
# 2            3          160       5/1/2019             15  $13,000.00
# 3            4            7      12/8/2019             23  $56,000.00
# 4            5          144      2/11/2019              7  $21,000.00
#
#    monthly_amt
# 0  $11,600.00
# 1  $14,600.00
# 2  $22,800.00
# 3  $11,400.00
# 4  $19,800.00

# %%
df_customers = pd.read_csv('../data/customers.csv')
df_customers.head()
# Out:
#    id       company         sector                                 industry  \
# 0   1     Bubblebox  Capital Goods            Military/Government/Technical
# 1   2          Izio         Energy                     Oil & Gas Production
# 2   3  Twitterworks            NaN                                      NaN
# 3   4          Viva    Health Care                    Major Pharmaceuticals
# 4   5   Jabberstorm     Technology  Computer Software: Prepackaged Software
#
#                       email                     address         city state  \
# 0  kyerson0@bizjournals.com             76 Randy Circle    San Diego    CA
# 1       farlet1@comcast.net  15360 Village Green Street      Spokane    WA
# 2        alerohan2@ox.ac.uk               29 Hovde Hill    Milwaukee    WI
# 3  wgiovanitti3@nytimes.com            074 Center Place       Topeka    KS
# 4         pscallon4@fc2.com                 4 Moose Way  Terre Haute    IN
#
#      zip
# 0  92170
# 1  99252
# 2  53234
# 3  66667
# 4  47805

# %%
df_customers.rename(columns={'id':'customer_id'}, inplace=True)
df_customers.head()
# Out:
#    customer_id       company         sector  \
# 0            1     Bubblebox  Capital Goods
# 1            2          Izio         Energy
# 2            3  Twitterworks            NaN
# 3            4          Viva    Health Care
# 4            5   Jabberstorm     Technology
#
#                                   industry                     email  \
# 0            Military/Government/Technical  kyerson0@bizjournals.com
# 1                     Oil & Gas Production       farlet1@comcast.net
# 2                                      NaN        alerohan2@ox.ac.uk
# 3                    Major Pharmaceuticals  wgiovanitti3@nytimes.com
# 4  Computer Software: Prepackaged Software         pscallon4@fc2.com
#
#                       address         city state    zip
# 0             76 Randy Circle    San Diego    CA  92170
# 1  15360 Village Green Street      Spokane    WA  99252
# 2               29 Hovde Hill    Milwaukee    WI  53234
# 3            074 Center Place       Topeka    KS  66667
# 4                 4 Moose Way  Terre Haute    IN  47805

# %%
df_customers.set_index('customer_id', inplace=True)
df_customers.head()
# Out:
#                   company         sector  \
# customer_id
# 1               Bubblebox  Capital Goods
# 2                    Izio         Energy
# 3            Twitterworks            NaN
# 4                    Viva    Health Care
# 5             Jabberstorm     Technology
#
#                                             industry  \
# customer_id
# 1                      Military/Government/Technical
# 2                               Oil & Gas Production
# 3                                                NaN
# 4                              Major Pharmaceuticals
# 5            Computer Software: Prepackaged Software
#
#                                 email                     address  \
# customer_id
# 1            kyerson0@bizjournals.com             76 Randy Circle
# 2                 farlet1@comcast.net  15360 Village Green Street
# 3                  alerohan2@ox.ac.uk               29 Hovde Hill
# 4            wgiovanitti3@nytimes.com            074 Center Place
# 5                   pscallon4@fc2.com                 4 Moose Way
#
#                     city state    zip
# customer_id
# 1              San Diego    CA  92170
# 2                Spokane    WA  99252
# 3              Milwaukee    WI  53234
# 4                 Topeka    KS  66667
# 5            Terre Haute    IN  47805

# %%
df_contracts = df_contracts.set_index('customer_id')
df_contracts.head()
# Out:
#              contract_id contract_start  contract_term      deposit  \
# customer_id
# 127                    1      8/17/2019             12  $53,000.00
# 119                    2      12/1/2019             22  $77,000.00
# 160                    3       5/1/2019             15  $13,000.00
# 7                      4      12/8/2019             23  $56,000.00
# 144                    5      2/11/2019              7  $21,000.00
#
#              monthly_amt
# customer_id
# 127          $11,600.00
# 119          $14,600.00
# 160          $22,800.00
# 7            $11,400.00
# 144          $19,800.00

# %%
df = df_contracts.join(df_customers, how='left')
df.head(25)
# Out:
#              contract_id contract_start  contract_term      deposit  \
# customer_id
# 1                     41      5/31/2019             24  $86,000.00
# 1                    358      6/18/2019             13  $74,000.00
# 1                    400      8/11/2019             19  $38,000.00
# 1                    424      3/13/2019             15  $77,000.00
# 1                    438     10/16/2019             22  $39,000.00
# 1                    657      8/27/2019             24  $67,000.00
# 1                    848     11/15/2019             11  $34,000.00
# 2                    308      3/28/2019             24  $14,000.00
# 2                    416     12/25/2019             18  $63,000.00
# 2                    645      9/20/2019              3  $34,000.00
# 2                    754     11/15/2019             12  $76,000.00
# 2                    954      1/31/2019             14  $15,000.00
# 3                    361      8/11/2019              1  $49,000.00
# 3                    596      12/1/2019              1  $19,000.00
# 3                    603       2/8/2019              7  $76,000.00
# 3                    759       6/3/2019              9  $91,000.00
# 3                    953       3/7/2019             18  $38,000.00
# 3                   1000      3/19/2019             16  $23,000.00
# 4                    378     12/10/2019             24  $46,000.00
# 4                    525       1/8/2019             15  $50,000.00
# 4                    896       2/5/2019             18  $85,000.00
# 5                    501     10/23/2019              5  $75,000.00
# 5                    707      5/23/2019              6  $46,000.00
# 6                     11      12/7/2019              4  $26,000.00
# 6                     26       3/3/2019             17  $69,000.00
#
#              monthly_amt       company         sector  \
# customer_id
# 1            $11,200.00      Bubblebox  Capital Goods
# 1            $19,000.00      Bubblebox  Capital Goods
# 1             $8,800.00      Bubblebox  Capital Goods
# 1            $14,300.00      Bubblebox  Capital Goods
# 1            $20,000.00      Bubblebox  Capital Goods
# 1            $22,400.00      Bubblebox  Capital Goods
# 1            $10,700.00      Bubblebox  Capital Goods
# 2             $6,900.00           Izio         Energy
# 2             $8,900.00           Izio         Energy
# 2            $19,100.00           Izio         Energy
# 2             $6,600.00           Izio         Energy
# 2            $24,300.00           Izio         Energy
# 3            $17,900.00   Twitterworks            NaN
# 3            $13,500.00   Twitterworks            NaN
# 3             $7,900.00   Twitterworks            NaN
# 3            $10,900.00   Twitterworks            NaN
# 3             $9,900.00   Twitterworks            NaN
# 3            $15,700.00   Twitterworks            NaN
# 4            $15,700.00           Viva    Health Care
# 4            $24,500.00           Viva    Health Care
# 4             $5,600.00           Viva    Health Care
# 5            $19,300.00    Jabberstorm     Technology
# 5            $19,600.00    Jabberstorm     Technology
# 6            $19,100.00        Teklist     Technology
# 6            $19,400.00        Teklist     Technology
#
#                                                       industry  \
# customer_id
# 1                                Military/Government/Technical
# 1                                Military/Government/Technical
# 1                                Military/Government/Technical
# 1                                Military/Government/Technical
# 1                                Military/Government/Technical
# 1                                Military/Government/Technical
# 1                                Military/Government/Technical
# 2                                         Oil & Gas Production
# 2                                         Oil & Gas Production
# 2                                         Oil & Gas Production
# 2                                         Oil & Gas Production
# 2                                         Oil & Gas Production
# 3                                                          NaN
# 3                                                          NaN
# 3                                                          NaN
# 3                                                          NaN
# 3                                                          NaN
# 3                                                          NaN
# 4                                        Major Pharmaceuticals
# 4                                        Major Pharmaceuticals
# 4                                        Major Pharmaceuticals
# 5                      Computer Software: Prepackaged Software
# 5                      Computer Software: Prepackaged Software
# 6            Radio And Television Broadcasting And Communic...
# 6            Radio And Television Broadcasting And Communic...
#
#                                 email                     address  \
# customer_id
# 1            kyerson0@bizjournals.com             76 Randy Circle
# 1            kyerson0@bizjournals.com             76 Randy Circle
# 1            kyerson0@bizjournals.com             76 Randy Circle
# 1            kyerson0@bizjournals.com             76 Randy Circle
# 1            kyerson0@bizjournals.com             76 Randy Circle
# 1            kyerson0@bizjournals.com             76 Randy Circle
# 1            kyerson0@bizjournals.com             76 Randy Circle
# 2                 farlet1@comcast.net  15360 Village Green Street
# 2                 farlet1@comcast.net  15360 Village Green Street
# 2                 farlet1@comcast.net  15360 Village Green Street
# 2                 farlet1@comcast.net  15360 Village Green Street
# 2                 farlet1@comcast.net  15360 Village Green Street
# 3                  alerohan2@ox.ac.uk               29 Hovde Hill
# 3                  alerohan2@ox.ac.uk               29 Hovde Hill
# 3                  alerohan2@ox.ac.uk               29 Hovde Hill
# 3                  alerohan2@ox.ac.uk               29 Hovde Hill
# 3                  alerohan2@ox.ac.uk               29 Hovde Hill
# 3                  alerohan2@ox.ac.uk               29 Hovde Hill
# 4            wgiovanitti3@nytimes.com            074 Center Place
# 4            wgiovanitti3@nytimes.com            074 Center Place
# 4            wgiovanitti3@nytimes.com            074 Center Place
# 5                   pscallon4@fc2.com                 4 Moose Way
# 5                   pscallon4@fc2.com                 4 Moose Way
# 6             kformigli5@symantec.com    085 Messerschmidt Street
# 6             kformigli5@symantec.com    085 Messerschmidt Street
#
#                     city state    zip
# customer_id
# 1              San Diego    CA  92170
# 1              San Diego    CA  92170
# 1              San Diego    CA  92170
# 1              San Diego    CA  92170
# 1              San Diego    CA  92170
# 1              San Diego    CA  92170
# 1              San Diego    CA  92170
# 2                Spokane    WA  99252
# 2                Spokane    WA  99252
# 2                Spokane    WA  99252
# 2                Spokane    WA  99252
# 2                Spokane    WA  99252
# 3              Milwaukee    WI  53234
# 3              Milwaukee    WI  53234
# 3              Milwaukee    WI  53234
# 3              Milwaukee    WI  53234
# 3              Milwaukee    WI  53234
# 3              Milwaukee    WI  53234
# 4                 Topeka    KS  66667
# 4                 Topeka    KS  66667
# 4                 Topeka    KS  66667
# 5            Terre Haute    IN  47805
# 5            Terre Haute    IN  47805
# 6            San Antonio    TX  78245
# 6            San Antonio    TX  78245

# %%
gk = df.groupby('deposit') 
gk.first()
# Out:
#               contract_id contract_start  contract_term  monthly_amt  \
# deposit
# $10,000.00            236       2/5/2019             12  $14,200.00
# $100,000.00           620     10/11/2019             20   $6,000.00
# $11,000.00            559       6/2/2019             11  $17,100.00
# $12,000.00            880      2/11/2019             24  $19,100.00
# $13,000.00            732      6/21/2019             13   $5,200.00
# ...                   ...            ...            ...          ...
# $95,000.00            329       8/2/2019              8  $21,600.00
# $96,000.00            430      1/22/2019              2  $14,300.00
# $97,000.00            303      12/9/2019             17   $6,300.00
# $98,000.00            949     12/28/2019              4  $16,800.00
# $99,000.00            108       7/3/2019              6  $20,600.00
#
#                   company                 sector  \
# deposit
# $10,000.00         Meedoo                Finance
# $100,000.00      Buzzbean  Consumer Non-Durables
# $11,000.00          Leexo            Health Care
# $12,000.00       Feedfire      Consumer Durables
# $13,000.00           Eare      Consumer Services
# ...                   ...                    ...
# $95,000.00    Twitterlist             Technology
# $96,000.00    Twitterlist             Technology
# $97,000.00    Twitterlist             Technology
# $98,000.00       Tanoodle            Health Care
# $99,000.00          Mycat                Finance
#
#                                              industry  \
# deposit
# $10,000.00                                Major Banks
# $100,000.00           Consumer Electronics/Appliances
# $11,000.00                      Major Pharmaceuticals
# $12,000.00                     Industrial Specialties
# $13,000.00              Real Estate Investment Trusts
# ...                                               ...
# $95,000.00    Computer Software: Prepackaged Software
# $96,000.00    Computer Software: Prepackaged Software
# $97,000.00    Computer Software: Prepackaged Software
# $98,000.00                      Major Pharmaceuticals
# $99,000.00                                Major Banks
#
#                                 email                 address           city  \
# deposit
# $10,000.00         ediscombe6@epa.gov        38 Shoshone Lane        El Paso
# $100,000.00           reslere@mac.com        7472 Tony Avenue          Bronx
# $11,000.00    lbarefordc@facebook.com    36154 Bunting Street  New York City
# $12,000.00            rrobynsm@ca.gov  777 La Follette Center     Saint Paul
# $13,000.00        shandrekp@amazon.de      212 Portage Center    Kansas City
# ...                               ...                     ...            ...
# $95,000.00         kgerhardt9@soup.io       567 Cascade Plaza      Vancouver
# $96,000.00         kgerhardt9@soup.io       567 Cascade Plaza      Vancouver
# $97,000.00         kgerhardt9@soup.io       567 Cascade Plaza      Vancouver
# $98,000.00        fchaytork@sogou.com      1 Armistice Avenue         Pueblo
# $99,000.00         kdurganb@europa.eu    97 Macpherson Street     Fort Wayne
#
#              state    zip
# deposit
# $10,000.00      TX  79994
# $100,000.00     NY  10459
# $11,000.00      NY  10131
# $12,000.00      MN  55114
# $13,000.00      KS  66112
# ...            ...    ...
# $95,000.00      WA  98664
# $96,000.00      WA  98664
# $97,000.00      WA  98664
# $98,000.00      CO  81005
# $99,000.00      IN  46825
#
# [91 rows x 12 columns]

# %%
int = df.deposit

# %%
gd = df.cumsum('deposit') 
gd.head(25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-954fbd600233> in <module>
# ----> 1 gd = df.cumsum('deposit')
#       2 gd.head(25)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in cum_func(self, axis, skipna, *args, **kwargs)
#   11268             axis = self._stat_axis_number
#   11269         else:
# > 11270             axis = self._get_axis_number(axis)
#   11271
#   11272         if axis == 1:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
#     409     @classmethod
#
# ValueError: No axis named deposit for object type <class 'pandas.core.frame.DataFrame'>
